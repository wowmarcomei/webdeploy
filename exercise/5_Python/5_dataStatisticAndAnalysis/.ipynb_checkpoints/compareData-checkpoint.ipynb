# %%
import pymongo
import charts
from string import punctuation
# Out:
# Server running in the folder /Users/meixuhong/workstation/exercise/5_Python/5_dataStatisticAndAnalysis at 127.0.0.1:49831

# %%
client = pymongo.MongoClient('localhost',27017)
ceshi = client['test']
item_info = ceshi['data_sample1']

# %%
for i in item_info.find().limit(300):
    print(i['area'])
# Out:
# ['西城', '-', '西单']
# ['朝阳', '-', '定福庄']
# ['朝阳', '-', '高碑店']
# None
# ['丰台']
# ['朝阳', '-', '定福庄']
# ['朝阳', '-', '国贸']
# ['朝阳', '-', '孙河']
# ['东城', '-', '东单']
# ['朝阳', '-', '望京']
# ['昌平', '-', '北七家']
# ['怀柔', '-', '怀柔城区']
# ['燕郊', '-', '燕顺路']
# ['海淀', '-', '蓟门桥']
# ['朝阳', '-', '东坝']
# ['海淀', '-', '北洼路']
# None
# ['通州', '-', '张家湾']
# ['海淀', '-', '上地']
# ['朝阳', '-', '定福庄']
# ['丰台']
# ['昌平']
# None
# ['海淀', '-', '知春路']
# ['朝阳', '-', '太阳宫']
# ['西城', '-', '南礼士路']
# ['丰台', '-', '总部基地']
# None
# ['大兴', '-', '旧宫']
# ['昌平', '-', '回龙观']
# ['海淀', '-', '苏州桥']
# ['海淀', '-', '上地']
# ['丰台']
# ['朝阳', '-', '劲松']
# ['大兴', '-', '瀛海镇']
# ['丰台']
# None
# ['朝阳', '-', '双桥']
# ['房山', '-', '良乡']
# ['大兴', '-', '西红门']
# ['海淀', '-', '香山']
# ['宣武', '-', '广安门外']
# ['丰台', '-', '宋家庄']
# ['大兴', '-', '西红门']
# ['通州', '-', '新华大街']
# ['西城', '-', '复兴门']
# ['通州', '-', '武夷花园']
# ['朝阳', '-', '劲松']
# ['海淀', '-', '四季青']
# ['通州', '-', '马驹桥']
# ['西城', '-', '西四']
# ['海淀', '-', '西二旗']
# ['昌平', '-', '沙河']
# ['朝阳', '-', '管庄']
# ...

# %%
#先来一段例子解释下punctuation的作用
#=================================================
# >>> import string
# >>> print（string.punctuation）
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# >>> '.' in string.punctuation
# 1
# >>> 'a' in string.punctuation
# 0
#=================================================
for i in item_info.find():
    if i['area']:
        area = [i for i in i['area'] if i not in punctuation]
    else:
        area = ['不明']
    item_info.update({'_id':i['_id']},{'$set':{'area':area}})
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:16: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.

# %%
for i in item_info.find().limit(300):
    print(i['area'])
# Out:
# ['西城', '西单']
# ['朝阳', '定福庄']
# ['朝阳', '高碑店']
# ['不明']
# ['丰台']
# ['朝阳', '定福庄']
# ['朝阳', '国贸']
# ['朝阳', '孙河']
# ['东城', '东单']
# ['朝阳', '望京']
# ['昌平', '北七家']
# ['怀柔', '怀柔城区']
# ['燕郊', '燕顺路']
# ['海淀', '蓟门桥']
# ['朝阳', '东坝']
# ['海淀', '北洼路']
# ['不明']
# ['通州', '张家湾']
# ['海淀', '上地']
# ['朝阳', '定福庄']
# ['丰台']
# ['昌平']
# ['不明']
# ['海淀', '知春路']
# ['朝阳', '太阳宫']
# ['西城', '南礼士路']
# ['丰台', '总部基地']
# ['不明']
# ['大兴', '旧宫']
# ['昌平', '回龙观']
# ['海淀', '苏州桥']
# ['海淀', '上地']
# ['丰台']
# ['朝阳', '劲松']
# ['大兴', '瀛海镇']
# ['丰台']
# ['不明']
# ['朝阳', '双桥']
# ['房山', '良乡']
# ['大兴', '西红门']
# ['海淀', '香山']
# ['宣武', '广安门外']
# ['丰台', '宋家庄']
# ['大兴', '西红门']
# ['通州', '新华大街']
# ['西城', '复兴门']
# ['通州', '武夷花园']
# ['朝阳', '劲松']
# ['海淀', '四季青']
# ['通州', '马驹桥']
# ['西城', '西四']
# ['海淀', '西二旗']
# ['昌平', '沙河']
# ['朝阳', '管庄']
# ['朝阳', '安贞']
# ['朝阳', 'CBD']
# ['朝阳', '大山子']
# ['崇文', '龙潭湖']
# ['朝阳', '朝阳公园']
# ['海淀']
# ['不明']
# ['通州', '果园']
# ['朝阳', '工体']
# ['不明']
# ['朝阳', '十八里店']
# ['朝阳', '欢乐谷']
# ['西城', '西直门']
# ['海淀', '永定路']
# ...

# %%
area_list = []
for i in item_info.find():
    area_list.append(i['area'][0])
# print(area_list)
area_index = list(set(area_list))  #去重复
print(area_index)
# Out:
# ['东城', '西城', '通州', '平谷', '附近', '海淀', '朝阳', '宣武', '门头沟', '不明', '昌平', '崇文', '房山', '北京周边', '大兴', '延庆', '燕郊', '怀柔', '石景山', '丰台', '顺义', '密云']

# %%
#=============================================
#--------------使用count计数-------------------
#=============================================
post_times = []
for index in area_index:
    post_times.append(area_list.count(index))
print(post_times)
# Out:
# [3155, 3376, 4924, 277, 3, 11768, 19224, 1803, 464, 15505, 4963, 1188, 1490, 520, 4856, 164, 541, 381, 1958, 7991, 1913, 386]

# %%
#=============================================
#-----定义函数data_gen，构造HighCharts字典-------
#=============================================
def data_gen(types):
    length = 0
    if length <= len(area_index):
        for area,times in zip(area_index,post_times):
            data = {
                'name':area,
                'data':[times],
                'type':types
            }
            yield data #返回数据，不同于return的是这个可以多次返回数据
            length += 1
#传入参数column构造highcharts要求的字典

for i in data_gen('column'):
    print(i)
# Out:
# {'type': 'column', 'data': [3155], 'name': '东城'}
# {'type': 'column', 'data': [3376], 'name': '西城'}
# {'type': 'column', 'data': [4924], 'name': '通州'}
# {'type': 'column', 'data': [277], 'name': '平谷'}
# {'type': 'column', 'data': [3], 'name': '附近'}
# {'type': 'column', 'data': [11768], 'name': '海淀'}
# {'type': 'column', 'data': [19224], 'name': '朝阳'}
# {'type': 'column', 'data': [1803], 'name': '宣武'}
# {'type': 'column', 'data': [464], 'name': '门头沟'}
# {'type': 'column', 'data': [15505], 'name': '不明'}
# {'type': 'column', 'data': [4963], 'name': '昌平'}
# {'type': 'column', 'data': [1188], 'name': '崇文'}
# {'type': 'column', 'data': [1490], 'name': '房山'}
# {'type': 'column', 'data': [520], 'name': '北京周边'}
# {'type': 'column', 'data': [4856], 'name': '大兴'}
# {'type': 'column', 'data': [164], 'name': '延庆'}
# {'type': 'column', 'data': [541], 'name': '燕郊'}
# {'type': 'column', 'data': [381], 'name': '怀柔'}
# {'type': 'column', 'data': [1958], 'name': '石景山'}
# ...

# %%
#=============================================
#--------------------绘制图标------------------
#=============================================
series = [data for data in data_gen('column')]
# print(series)
charts.plot(series,show='inline',options=dict(title=dict(text='七日内北京城区二手物品发帖量')))
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;font-family:sans-serif}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# ...
